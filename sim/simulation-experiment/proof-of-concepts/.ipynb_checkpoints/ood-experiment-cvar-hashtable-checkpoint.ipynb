# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import Parallel, delayed
import itertools
import pymoo
import scipy
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.special import expit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
from tqdm.notebook import tqdm
from datetime import datetime
from pymoo.core.problem import ElementwiseProblem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PM
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.termination import get_termination
from pymoo.factory import get_problem
from pymoo.optimize import minimize
#%matplotlib notebook

random_seed = 1
np.random.seed(seed=random_seed)

import warnings
warnings.filterwarnings('ignore')

# %%
import os
path = os.path.join(os.getcwd(), "plot/")
today=datetime.today().strftime('%Y-%m-%d')

# %% [markdown]
# **Preliminaries** In the following, the classes are defined to initiate the aggregation functions $\rho_{\alpha}$ and the aggregated risk minimization (ARM) optimization for a simple 1D and 2D regression task.

# %%
def f_hat(experiment):
    if experiment == "1D_linear":
        f = lambda x, theta: x * theta
    elif experiment == "1D_nonlinear":
        f = lambda x, theta: np.exp(x * theta)
    if experiment == "2D_linear":
        f = lambda x, theta: (x @ theta)
    elif experiment == "2D_nonlinear":
        f = lambda x, theta: np.exp(x @ theta) 
    return f

# %%
class aggregation_function:
    
    """ This class aggregates the risks. """
    def __init__(self, name:str):
        """ Construct the aggregation function.
        
        Parameters
        -----------
        name : str
            the name of the function to aggregate the risks
        """       
        self.name = name
    
    def aggregate(self, risks:list, alpha:int) -> float:
            
        """Aggregates a list of risks according to an aggregation function rho. 

        Parameters
        ----------
        risks : list
        alpha : int

        Returns
        ------
        aggregated_risks : float
        
        Examples
        --------
        >>> aggregation_function(name="cvar").aggregate([1,2,3,4], 0.5)
        
        """        
        if self.name == "cvar":
            aggregated_risks = self.__cvar__(risks, alpha)
        else:
            raise NotImplementedError("Currently, only CVaR is implemented.")
        return aggregated_risks
    
    def __cvar__(self, risks:list, alpha:float) -> float:
        
        """Calculate the CVaR value for a list of risks. 

        Parameters
        ----------
        risks : list
        alpha : float

        Returns
        ------
        cvar : float
        """
        risks = np.array(risks)
        var = np.quantile(risks,alpha, method='interpolated_inverted_cdf')
        cvar = risks[risks > var].mean()
        return cvar

# %%
class ARM_Regression(BaseEstimator, RegressorMixin):
    def __init__(self,name,experiment="1D_linear"):
        
        """ Consutruct th aggregation function.
        
        Parameters
        -----------
        name : str
        the name of the function to aggregate the risks
        
        experiment : str, required
        the name of experimental setting
        """        
        self.aggregator = aggregation_function(name=name)
        self.experiment = experiment
        
    def fit(self, f, env_dict, alpha):
        
        """Fit the coefficients of a function f. 

        Parameters
        ----------
        env_dict : dict
        alpha : int

        Returns
        ------
        coef : float
        """
        d = env_dict[0]['x'].shape[1]
        def return_risks(env_dict):
            return lambda coefs : [mean_squared_error(env_dict[e]['y'],f(env_dict[e]['x'], coefs)) for e in env_dict.keys()]
        parameterized_risks = return_risks(env_dict)
        aggregated_risk_fn = lambda coefs: self.aggregator.aggregate(parameterized_risks(coefs), alpha)                                   
        self.coef_ = scipy.optimize.minimize(aggregated_risk_fn, x0=np.random.uniform(0, 1, d)).x
        
        return self.coef_

    def predict(self, X):
        
        """Make the predictions. 

        Parameters
        ----------
        X : dict

        Returns
        ------
        pred : predictions
        """
            
        check_is_fitted(self)
        X = check_array(X)
        pred = X@self.coef_ + self.intercept_
        return pred

# %%
class RiskVector(ElementwiseProblem):

    def __init__(self, env_dict, alphas, fun):
        super().__init__(n_var=env_dict[0]['x'].shape[1], n_obj=len(alphas), 
                         xl=np.array([0]*env_dict[0]['x'].shape[1]), 
                         xu=np.array([1]*env_dict[0]['x'].shape[1]))
        self.env_dict = env_dict 
        self.alphas = alphas 
        self.fun = fun
    def _evaluate(self, x, out, *args, **kwargs):
        oracle = []
        for alpha in self.alphas:
            risks = [mean_squared_error(self.env_dict[e]['y'],self.fun(self.env_dict[e]['x'], x)) for e in self.env_dict.keys()]
            risks = np.array(risks)
            var = np.quantile(risks, alpha, method='interpolated_inverted_cdf')
            cvar = risks[risks > var].mean()
            oracle.append(cvar)
        out["F"]=oracle

# %%
class ARM_Multiobjective_Regression(BaseEstimator, RegressorMixin):
    def __init__(self,name,experiment="1D_linear"):
        
        """ Consutruct th aggregation function.
        
        Parameters
        -----------
        name : str
        the name of the function to aggregate the risks
        
        experiment : str, required
        the name of experimental setting
        """        
        self.experiment = experiment
    
    def pareto_front(self, f, env_dict, alphas):
        
        """Fit the coefficients of a function f. 

        Parameters
        ----------
        env_dict : dict
        alphas : list of ints 

        Returns
        ------
        coef : float
        """
        d = env_dict[0]['x'].shape[1]
        
        problem = RiskVector(env_dict, alphas, f)
        
        algorithm = NSGA2(
            pop_size=400,
            n_offsprings=10,
            sampling=FloatRandomSampling(),
            crossover=SBX(prob=0.9, eta=15),
            mutation=PM(eta=20),
            eliminate_duplicates=True
        )

        termination = get_termination("n_gen", 20)


        result = minimize(problem,
               algorithm,
               termination,
               seed=1,
               save_history=True,
               verbose=True)

        return result.X

# %% [markdown]
# **Experiment 1** We assume the following *linear* data generation process $$Y(X) = X*\theta_{e}+\epsilon$$ and *nonlinear* data generation process $$Y(X) = sin(X*\theta_{e})+\epsilon$$.
#
# **Experiment 1A** Assume a linear model $Y_{e}=\theta_{e}X+\epsilon$, where $X \sim \mathcal{N}(2,0.2)$ and $\epsilon\sim \mathcal{N}(0,0.1)$. We simulate different environments by drawing $\theta$ from a beta distribution $Beta(0.1,0.2)$. In total, we generate for 25 environments 100 observations each.
#
# **Experiment 1B** Assume the same setting as in Experiment 1, however, in contrast, we simulate different environments by drawing $\theta$ from a uniform distribution $\ \mathcal{U}(0,1)$. In total, we generate for 25 environments 100 observations each.

# %%
class data_generator_1D:
    
    """ This class generates the 1D simulation data. """
    

    def __init__(self, num_envs = 250, size = (100,1), theta="uniform", experiment="1D_linear"):
        
        """ Construct the aggregation function.
        
        Parameters
        -----------
        experiment : str, optional
            the name of the experimental setting (whether we want f to be linear n X or non-linear)
        num_envs : int, optional
            the number of environments
        size : tuple, optional
            the size of the datset (number of observations, number of features)
        theta : str, optional
            the distrubution from which we sample the true thetas for each environment
        """
        
        self.num_envs = num_envs
        self.size = size
        self.theta = theta
        self.experiment = experiment
        self.description = f"{theta}_{experiment}"
    
    def generate(self, f) -> dict:           
        """Aggregates a list of risks. 

        Returns
        ------
        env_dict : dict
        Examples
        --------
        >>> data_generator_1D(num_envs = 250, size = (100,1), theta="uniform", experiment="1D_linear").generate()
        """
        env_list = [f'e_{i}' for i in range(1,num_envs+1,1)]
        env_dict = dict(list(enumerate(env_list)))
        for e in env_dict.keys():

            theta_true=np.random.uniform(0,1) if self.theta == "uniform" else np.random.beta(0.1,0.2)

            x=np.random.normal(loc=1, scale=0.5, size=self.size)
            noise=np.random.normal(loc=0, scale=0.05, size=self.size)
            y = f(x,theta_true)+noise

            env_dict[e] = {'x': x,'y': y,'theta_true': theta_true, 'env': [e]*size[0]}

        return env_dict

# %%
# Intitialize the experiment and generate the data
num_envs=25
size = (100,1)
theta="beta" 
experiment="1D_nonlinear"
rho="cvar"

f = f_hat(experiment)
data_generator = data_generator_1D(num_envs = num_envs, size = size, theta=theta, experiment=experiment)
data_dict = data_generator.generate(f).copy()

description = data_generator.description

fig, ax = plt.subplots(1,1, figsize=(8,6))

X_train = [data_dict[e]['x'].ravel() for e in data_dict.keys()]
X_train = np.array([item for sublist in X_train for item in sublist]).reshape(-1,1)
Y_train = [data_dict[e]['y'] for e in data_dict.keys()]
Y_train = np.array([item for sublist in Y_train for item in sublist]).reshape(-1,1)

ax.scatter(y=Y_train, x=X_train, s=3, c="grey", alpha=0.05, label="Training envs")
ax.legend(loc='upper left')

# %%
#Run the ARM Multiobjective regression task
results = pd.DataFrame(columns = ["alpha", "theta_hat", "cvar"])
fig, ax = plt.subplots(1, 1, sharey=True, figsize=(8,6))
step = 0.01
rg = np.arange(0,1,step)
diverging_colors = sns.color_palette("RdBu", len(rg))
j=1


for i in tqdm(rg):
    theta_hat = ARM_Regression(name=rho, experiment=experiment).fit(f, data_dict, i)  
    
    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta_hat)) for e in data_dict.keys()]
    #print(risks)
    cvar_emp = aggregation_function(name="cvar").aggregate(risks, i)
             
    sns.kdeplot(risks, ax=ax,color=diverging_colors[len(rg)-j], label=str(i/100))
    
    results.at[i, "alpha"] = i
    results.at[i, "theta_hat"] = theta_hat[0]
    results.at[i, "cvar"] = cvar_emp
    j+=1
    
ax.legend(bbox_to_anchor=(1.02, 1.02), title=r"$\alpha$", loc='upper left')
ax.set_title(r"Distribution of the risks on the training data ($\alpha$)")

norm = plt.Normalize(0.05, 0.95)
sm = plt.cm.ScalarMappable(cmap="RdBu_r", norm=norm)
sm.set_array([])

ax.get_legend().remove()
ax.figure.colorbar(sm).set_label(label= r'$\alpha$',labelpad=5,size=12)

plt.tight_layout()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#Run the ARM Multiobjective 
pareto_rg = np.arange(0,1,0.01)
theta_hats = ARM_Multiobjective_Regression(name=rho, experiment=experiment).pareto_front(f, data_dict, pareto_rg)
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      400 |    114 |             - |             -
#      2 |      410 |    119 |  0.0004629867 |             f
#      3 |      420 |    126 |  0.0028422814 |             f
#      4 |      430 |    131 |  0.0058726112 |         ideal
#      5 |      440 |    136 |  0.0014483186 |             f
#      6 |      450 |    138 |  0.0017233375 |             f
#      7 |      460 |    141 |  0.0021983280 |             f
#      8 |      470 |    145 |  0.0032008950 |             f
#      9 |      480 |    148 |  0.0011272504 |             f
#     10 |      490 |    152 |  0.0026814420 |             f
#     11 |      500 |    155 |  0.0004483109 |             f
#     12 |      510 |    157 |  0.0241524510 |         nadir
#     13 |      520 |    162 |  0.0005022261 |             f
#     14 |      530 |    167 |  0.0013314615 |             f
#     15 |      540 |    171 |  0.0016782746 |             f
#     16 |      550 |    173 |  0.0024486724 |             f
#     17 |      560 |    177 |  0.0033638832 |             f
#     18 |      570 |    180 |  0.0003794041 |             f
#     19 |      580 |    186 |  0.0017935525 |             f
#     20 |      590 |    192 |  0.0379317678 |         nadir

# %%
alpha_hats = [results["alpha"].iloc[np.argmin((theta_hat-results["theta_hat"])**2)] for theta_hat in theta_hats]
plot = sns.displot(alpha_hats, bins=100)
plot.fig.suptitle(r"Distribution of the $\alpha$ for multiobjective (146 solutions).")
plot.set_axis_labels(x_var=r"$\alpha$ (Resolution {})".format(step))

# %%
cvar_hats = []
for index in range(len(alpha_hats)):
    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta_hats[index])) for e in data_dict.keys()]
    cvar = aggregation_function(name="cvar").aggregate(risks, alpha_hats[index])
    cvar_hats.append(cvar)

# %%
fig, ax = plt.subplots(1, 1, sharey=True, figsize=(8,6))
index = np.argmax(abs(results["cvar"][alpha_hats]-np.array(cvar_hats)))
diverging_colors = sns.color_palette("RdBu", 2)
print(index)
retrived_alpha, computed_cvar = alpha_hats[index], cvar_hats[index]
print("alpha:", retrived_alpha) 
print(results["theta_hat"][retrived_alpha],results["cvar"][retrived_alpha])
print(theta_hats[index], computed_cvar)
risks1 = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], results["theta_hat"][retrived_alpha])) for e in data_dict.keys()]
risks2 = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta_hats[index])) for e in data_dict.keys()]
sns.kdeplot(risks1,ax=ax,color=diverging_colors[0],label="independent")
sns.kdeplot(risks2, ax=ax,color=diverging_colors[1], label="multi")

ax.legend()
ax.set_title("Distribution of risk for largest difference in cvar")
# Out:
# 174
# alpha: 0.93
# 0.6615659651799245 2.0326834022114157
# [0.65285419] 2.111740378117018
# Text(0.5, 1.0, 'Distribution of risk for largest difference in cvar')

# %%
#Plot the CVAR landscape and the estimated thetas
step_size= 0.1
rg_alpha = np.arange(0, 1, step_size)
rg_theta = np.arange(0, 1, step_size)
output_list = list(itertools.product(*[rg_alpha, rg_theta]))

def array_for_heatmap(data_dict, alpha, theta):

    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta)) for e in data_dict.keys()]
    cvar = aggregation_function(name="cvar").aggregate(risks, alpha)
    
    return [np.round(alpha, 3), np.round(theta, 3), np.round(cvar, 3)]

temp = Parallel(n_jobs=8)(delayed(array_for_heatmap)(data_dict, j[0], j[1]) for j in tqdm(output_list))

# Prepare the data for the landscape plot
index, columns = np.unique([i[0] for i in temp]), np.unique([i[0] for i in temp])

landscape = pd.DataFrame(index=index, columns=columns)

for i in temp:
    landscape.at[i[0], i[1]] = float(i[2]) #if not np.nan else np.nan
    
landscape = landscape.sort_index(ascending=False).apply(pd.to_numeric, errors='coerce')

del temp


fig, ax = plt.subplots(1,1, figsize=(8,6))

vmin, vmax=0.0, 1.5

img = ax.imshow(landscape,extent=[0,1,0,1], interpolation='bilinear', cmap="Greens", vmin=vmin, vmax=vmax) #extent=[0,1,0,1]

plt.xlabel(r'$\Theta$', fontsize = 16)
plt.ylabel(r'$\alpha$', fontsize = 16)
img = ax.scatter(y=alpha_hats, x=theta_hats, c=cvar_hats, edgecolors='black', cmap = 'Greens', vmin=vmin, vmax=vmax, label="MultiObjective")
ax.set_title(r"Landscape for $CVaR_{\alpha}(\theta)$ and circles represent $\hat{\theta}$")
plt.legend()
fig.colorbar(img).set_label(label='CVaR value',labelpad=5,size=12)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#Plot the CVAR landscape and the estimated thetas
step_size= 0.1
rg_alpha = np.arange(0, 1, step_size)
rg_theta = np.arange(0, 1, step_size)
output_list = list(itertools.product(*[rg_alpha, rg_theta]))

def array_for_heatmap(data_dict, alpha, theta):

    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta)) for e in data_dict.keys()]
    cvar = aggregation_function(name="cvar").aggregate(risks, alpha)
    
    return [np.round(alpha, 3), np.round(theta, 3), np.round(cvar, 3)]

temp = Parallel(n_jobs=8)(delayed(array_for_heatmap)(data_dict, j[0], j[1]) for j in tqdm(output_list))

# Prepare the data for the landscape plot
index, columns = np.unique([i[0] for i in temp]), np.unique([i[0] for i in temp])

landscape = pd.DataFrame(index=index, columns=columns)

for i in temp:
    landscape.at[i[0], i[1]] = float(i[2]) #if not np.nan else np.nan
    
landscape = landscape.sort_index(ascending=False).apply(pd.to_numeric, errors='coerce')

del temp


fig, ax = plt.subplots(1,1, figsize=(8,6))

vmin, vmax=0.0, 1.5

img = ax.imshow(landscape,extent=[0,1,0,1], interpolation='bilinear', cmap="Greens", vmin=vmin, vmax=vmax) #extent=[0,1,0,1]

plt.xlabel(r'$\Theta$', fontsize = 16)
plt.ylabel(r'$\alpha$', fontsize = 16)
img = ax.scatter(y=results.alpha, x=results.theta_hat, c = results.cvar, edgecolors='black', cmap = 'Greens', vmin=vmin, vmax=vmax, label="Independent")
ax.set_title(r"Landscape for $CVaR_{\alpha}(\theta)$ and circles represent $\hat{\theta}$")
fig.colorbar(img).set_label(label='CVaR value',labelpad=5,size=12)
plt.legend()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#Plot the data and the estimated regression function
j=1
fig, ax = plt.subplots(1,1, figsize=(8,6))

X_train = [data_dict[e]['x'].ravel() for e in data_dict.keys()]
X_train = np.array([item for sublist in X_train for item in sublist]).reshape(-1,1)
Y_train = [data_dict[e]['y'] for e in data_dict.keys()]
Y_train = np.array([item for sublist in Y_train for item in sublist]).reshape(-1,1)

ax.scatter(y=Y_train, x=X_train, s=3, c="grey", alpha=0.05, label="Training envs")
ax.legend(loc='upper left')

diverging_colors = sns.color_palette("RdBu", len(results))

for index, row in results.iterrows():

    x_plt = np.arange(0,4,0.1)
    ax.plot(x_plt, f(x_plt, row['theta_hat']), c =diverging_colors[len(results)-j], alpha=0.5, label="Test envs")
    j+=1

norm = plt.Normalize(0.05, 0.95)
sm = plt.cm.ScalarMappable(cmap="RdBu_r", norm=norm)
sm.set_array([])

ax.get_legend().remove()
ax.figure.colorbar(sm).set_label(label= r'$\alpha$',labelpad=5,size=12)

ax.axis(xmin=0,xmax=3)
ax.axis(xmin=0,xmax=3)

ax.set_title("Generated data")
ax.set_xlabel(r"$X$")
ax.set_ylabel(r"$Y$")

ax.set_xlabel(r"$X$")
ax.set_title(r"Estimated regression functions $h(\alpha,x)$")
# Out:
# Text(0.5, 1.0, 'Estimated regression functions $h(\\alpha,x)$')

# %%
import numpy as np
import matplotlib.pyplot as plt

alpha_plt = np.arange(0, 1, 0.01)
x_plt = np.arange(4, 6, 0.01)

h = np.array([f(x,theta) for theta in list(results['theta_hat']) for x in x_plt]).reshape(len(alpha_plt), len(x_plt))

plt.figure()
plt.pcolor(x_plt, alpha_plt, h, cmap=plt.get_cmap('RdPu'))
contour = plt.contour(x_plt, alpha_plt, h, colors='black', levels=10)  # Add contour lines
plt.xlabel(r"$X$")
plt.ylabel(r"$\alpha$")
plt.title(r"$h(X,\alpha)$")
plt.colorbar(contour)  # Add color to the color bar
plt.show()

# %% [markdown]
# **Experiment 2** We assume the following *linear* data generation process $$Y(X_{1},X_{2}) = X_{1}^{2}*\theta_{1,e}+X_{2}*\theta_{2,e}+\epsilon$$ and the following non-linear data generation process
#
# $$Y(X_{1},X_{2}) = \exp^{-\sqrt{X_{1}*\theta_{1,e}+X_{2}*\theta_{2,e}}}+\epsilon$$

# %%
class data_generator_2D:
    
    """ This class generates the 2D simulation data. """
    

    def __init__(self, num_envs = 250, size = (100,2), experiment="linear", theta="beta"):
        
        """ Construct the aggregation function.
        
        Parameters
        -----------
        experiment : str, optional
            the name of the experimental setting (whether we want f to be linear n X or non-linear)
        num_envs : int, optional
            the number of environments
        size : tuple, optional
            the size of the datset (number of observations, number of features)
        """
        
        self.num_envs = num_envs
        self.size = size
        self.experiment = experiment
        self.description = f"{theta}_{experiment}"
        self.theta = theta 
    def generate(self, f) -> dict:
            
        """Aggregates a list of risks. 

        Returns
        ------
        env_dict : dict
        
        Examples
        --------
        >>> data_generator_2D(num_envs = 250, size = (100,2), experiment="linear").generate()
        
        """
        env_list = [f'e_{i}' for i in range(1,num_envs+1,1)]
        env_dict = dict(list(enumerate(env_list)))
        for e in env_dict.keys():

            theta_true_1 = np.random.uniform(0,1) if self.theta == "uniform" else np.random.beta(0.1,0.2)
            theta_true_2 = np.random.uniform(0,1) if self.theta == "uniform" else np.random.beta(0.1,0.2)
            theta_true = np.array([theta_true_1, theta_true_2])[:,None]
            x=np.random.normal(loc=(0,0), scale=(0.5, 0.5), size=size)
            noise=np.random.normal(loc=0, scale=0.05)
            y=f(x, theta_true)+noise
            env_dict[e] = {'x': x,'y': y,'theta_true': (theta_true_1, theta_true_2), 'env': [0]*size[0] if e < 100 else [1]*size[0]}

        return env_dict

# %%
# Intitialize the experiment and generate the data
num_envs=25
size = (100,2)
experiment="2D_linear"
rho="cvar"

data_generator = data_generator_2D(num_envs = num_envs, size = size, experiment=experiment, theta="beta")
f = f_hat(experiment)
data_dict = data_generator.generate(f).copy()

description = data_generator.description

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(projection='3d')

X_0_train = [data_dict[e]['x'][:,0:1].ravel() for e in data_dict.keys()]
X_0_train = np.array([item for sublist in X_0_train for item in sublist]).reshape(-1,1)

X_1_train = [data_dict[e]['x'][:,1:2].ravel() for e in data_dict.keys()]
X_1_train = np.array([item for sublist in X_1_train for item in sublist]).reshape(-1,1)

Y_train = [data_dict[e]['y'] for e in data_dict.keys()]
Y_train = np.array([item for sublist in Y_train for item in sublist]).reshape(-1,1)

ax.scatter(X_0_train, X_1_train, Y_train, s=3,c = "r", alpha=0.3, label="Training envs")

plt.legend(loc='upper left')

ax.set_xlabel(r"$X_1$", fontsize=12)
ax.set_ylabel(r"$X_2$", fontsize=12)
ax.set_zlabel(r"$Y$", fontsize=12)

plt.show()

# %%
results_independent = pd.DataFrame(columns = ["alpha", "theta_hat", "cvar"])
fig, ax = plt.subplots(1, 1, sharey=True, figsize=(10,5))
rg = np.arange(0,1,0.05)

diverging_colors = sns.color_palette("RdBu", len(rg))
j=1

for i in tqdm(rg):
    theta_hat = ARM_Regression(name=rho, experiment=experiment).fit(f, data_dict, i)   
    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta_hat)) for e in data_dict.keys()]
    #print(risks)
    sns.kdeplot(risks, ax=ax,color=diverging_colors[len(rg)-j], label=str(i))
    
    
    cvar_emp = aggregation_function(name="cvar").aggregate(risks, i)
    results_independent.at[i, "alpha"] = i/100
    results_independent.at[i, "theta_hat"] = theta_hat
    results_independent.at[i, "cvar"] = cvar_emp
    j+=1
    
ax.legend(bbox_to_anchor=(1.02, 1.02), title=r"$\alpha$", loc='upper left')
ax.set_title(r"Distribution of the risks on the training data ($\alpha$)")

norm = plt.Normalize(0.05, 0.95)
sm = plt.cm.ScalarMappable(cmap="RdBu_r", norm=norm)

sm.set_array([])

ax.get_legend().remove()
ax.figure.colorbar(sm).set_label(label= r'$\alpha$',labelpad=5,size=12)

plt.tight_layout()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
results_multi = pd.DataFrame(columns = ["theta_hat"])
fig, ax = plt.subplots(1, 1, sharey=True, figsize=(10,5))
rg = np.arange(0,1,0.05)

diverging_colors = sns.color_palette("RdBu", len(rg))
theta_hats = ARM_Multiobjective_Regression(name=rho, experiment=experiment).pareto_front(f, data_dict, rg)
diverging_colors = sns.color_palette("RdBu", len(rg)*len(theta_hats))
for k, theta_hat in enumerate(theta_hats):
    risks = [mean_squared_error(data_dict[e]['y'], f(data_dict[e]['x'], theta_hat)) for e in data_dict.keys()]
    sns.kdeplot(risks, ax=ax)
    results_multi.at[k, "theta_hat"] = theta_hat
ax.legend(bbox_to_anchor=(1.02, 1.02), title=r"$\alpha$", loc='upper left')
ax.set_title(r"Distribution of the risks on the training data ($\alpha$)")

norm = plt.Normalize(0.05, 0.95)
sm = plt.cm.ScalarMappable(cmap="RdBu_r", norm=norm)

sm.set_array([])

ax.get_legend().remove()
ax.figure.colorbar(sm).set_label(label= r'$\alpha$',labelpad=5,size=12)

plt.tight_layout()
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      400 |     11 |             - |             -
#      2 |      410 |     11 |  0.000000E+00 |             f
#      3 |      420 |     12 |  0.0007735746 |             f
#      4 |      430 |     13 |  0.0095017251 |         ideal
#      5 |      440 |     13 |  0.000000E+00 |             f
#      6 |      450 |     15 |  0.0258387432 |             f
#      7 |      460 |     15 |  0.000000E+00 |             f
#      8 |      470 |     15 |  0.000000E+00 |             f
#      9 |      480 |     16 |  0.0936900272 |         nadir
#     10 |      490 |     16 |  0.000000E+00 |             f
#     11 |      500 |     15 |  0.0279709888 |         ideal
#     12 |      510 |     16 |  0.0093892013 |             f
#     13 |      520 |     17 |  0.0126672815 |             f
#     14 |      530 |     18 |  0.0084712225 |             f
#     15 |      540 |     19 |  0.0329278358 |             f
#     16 |      550 |     21 |  0.0323338111 |             f
#     17 |      560 |     22 |  0.0192770661 |             f
#     18 |      570 |     23 |  0.0063785623 |             f
#     19 |      580 |     23 |  0.000000E+00 |             f
#     20 |      590 |     25 |  0.0147119549 |             f
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(projection='3d')
theta_hat_0 = [results_independent['theta_hat'][key][0] for key in np.arange(0,1,0.05)]
theta_hat_1 = [results_independent['theta_hat'][key][1] for key in np.arange(0,1,0.05)]
ax.scatter(theta_hat_0, theta_hat_1, results_independent.alpha, alpha=0.3, label="Training envs")
ax.plot3D(theta_hat_0, theta_hat_1, results_independent.alpha,)
ax.set_xlabel(r"$\hat{\theta}_{0}$", fontsize=12)
ax.set_ylabel(r"$\hat{\theta}_{1}$", fontsize=12)
ax.set_zlabel(r"$\alpha$", fontsize=12, rotation=90)
ax.zaxis.labelpad=-0.7
plt.title("Independent Objectives")
# Out:
# Text(0.5, 0.92, 'Independent Objectives')

# %%
theta_hat_0 = [results_independent['theta_hat'][key][0] for key in np.arange(0,1,0.05)]
theta_hat_1 = [results_independent['theta_hat'][key][1] for key in np.arange(0,1,0.05)]
diverging_colors = sns.color_palette("RdBu", len(results_independent))
sc=plt.scatter(theta_hat_0, theta_hat_1, c = diverging_colors[::-1])
plt.xlabel(r"$\hat{\theta}_{0}$", fontsize=12)
plt.ylabel(r"$\hat{\theta}_{1}$", fontsize=12)
norm = plt.Normalize(0.05, 0.95)
sm = plt.cm.ScalarMappable(cmap="RdBu_r", norm=norm)
plt.colorbar(sm)
plt.title("Independent Objectives")
# Out:
# Text(0.5, 1.0, 'Independent Objectives')

# %%
alpha_hats = [results["alpha"].iloc[np.argmin(np.linalg.norm(theta_hat-results_multi["theta_hat"]))] for theta_hat in theta_hats]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 alpha_hats = [results["alpha"].iloc[np.argmin(np.linalg.norm(theta_hat-results_multi["theta_hat"]))] for theta_hat in theta_hats]
#
# Cell In[37], line 1, in <listcomp>(.0)
# ----> 1 alpha_hats = [results["alpha"].iloc[np.argmin(np.linalg.norm(theta_hat-results_multi["theta_hat"]))] for theta_hat in theta_hats]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2032, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2029 def __array_ufunc__(
#    2030     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031 ):
# -> 2032     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:253, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     250     return result
#     252 # for binary ops, use our custom dunder methods
# --> 253 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     254 if result is not NotImplemented:
#     255     return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/ops_dispatch.pyx:91, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/common.py:69, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      65             return NotImplemented
#      67 other = item_from_zerodim(other)
# ---> 69 return method(self, other)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:104, in OpsMixin.__rsub__(self, other)
#     102 @unpack_zerodim_and_defer("__rsub__")
#     103 def __rsub__(self, other):
# --> 104     return self._arith_method(other, roperator.rsub)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:5526, in Series._arith_method(self, other, op)
#    5523 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    5525 with np.errstate(all="ignore"):
# -> 5526     result = ops.arithmetic_op(lvalues, rvalues, op)
#    5528 return self._construct_result(result, name=res_name)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:224, in arithmetic_op(left, right, op)
#     219 else:
#     220     # TODO we should handle EAs consistently and move this check before the if/else
#     221     # (https://github.com/pandas-dev/pandas/issues/41165)
#     222     _bool_arith_check(op, left, right)
# --> 224     res_values = _na_arithmetic_op(left, right, op)
#     226 return res_values
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:166, in _na_arithmetic_op(left, right, op, is_cmp)
#     163     func = partial(expressions.evaluate, op)
#     165 try:
# --> 166     result = func(left, right)
#     167 except TypeError:
#     168     if is_object_dtype(left) or is_object_dtype(right) and not is_cmp:
#     169         # For object dtype, fallback to a masked operation (only operating
#     170         #  on the non-missing values)
#     171         # Don't do this for comparisons, as that will handle complex numbers
#     172         #  incorrectly, see GH#32047
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     236 if op_str is not None:
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      67 if _TEST_MODE:
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/roperator.py:13, in rsub(left, right)
#      12 def rsub(left, right):
# ---> 13     return right - left
#
# ValueError: operands could not be broadcast together with shapes (2,) (25,)

# %%
theta_hat_0 = [results_multi['theta_hat'][key][0] for key in range(len(theta_hats))]
theta_hat_1 = [results_multi['theta_hat'][key][1] for key in range(len(theta_hats))]
diverging_colors = sns.color_palette("RdBu", len(results_independent))
sc=plt.scatter(theta_hat_0, theta_hat_1, c = )
plt.xlabel(r"$\hat{\theta}_{0}$", fontsize=12)
plt.ylabel(r"$\hat{\theta}_{1}$", fontsize=12)
plt.title("Multi Objective Optimization")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 np.array(results_multi["theta_hat"]).vstack()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'vstack'
